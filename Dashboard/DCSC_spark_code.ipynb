# %%
! pip install pyspark boto3
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Collecting boto3
#   Downloading boto3-1.34.2-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Collecting botocore<1.35.0,>=1.34.2 (from boto3)
#   Downloading botocore-1.34.2-py3-none-any.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 27.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.10.0,>=0.9.0 (from boto3)
#   Downloading s3transfer-0.9.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.2->boto3) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.2->boto3) (2.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.2->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.34.2 botocore-1.34.2 jmespath-1.0.1 s3transfer-0.9.0

# %%
import pandas as pd
import pyspark
import boto3

# %%
from pyspark.sql import SparkSession

# %%
s3 = boto3.resource(
    service_name = 's3',
    region_name = 'us-east-2',
    aws_access_key_id = '',
    aws_secret_access_key = ''
)

# %%
obj = s3.Bucket('dsc-bucket-1').Object('raw/2023-12-12_open_fda_raw.csv').get()
pd_df = pd.read_csv(obj['Body'],index_col=0)

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://6db5f9814857:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>transform</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#df = spark.read.option('header','true').csv('/content/2023-12-12_open_fda_raw.csv')
df = spark.createDataFrame(pd_df)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import FloatType
import re
import random

# Create a Spark session
spark = SparkSession.builder.appName("example").getOrCreate()

# Define a UDF (User Defined Function) to extract numeric values from text
def extract_numeric_udf(text):
    if isinstance(text, str):
        # Use regular expression to find numeric values (including commas and dots)
        numeric_values = re.findall(r'\d[\d,]*(?:\.\d+)?', text)

        # Convert the extracted numbers to floats (considering commas)
        numeric_values = [float(value.replace(',', '')) for value in numeric_values]

        # Sum all numeric values
        total = sum(numeric_values)

        return total
    else:
        return None  # Return None for non-string or None values

# Register the UDF with Spark
extract_numeric_spark_udf = udf(extract_numeric_udf, FloatType())

# Apply the UDF to the 'product_quantity' column and create a new 'product_quantity_cleaned' column
df = df.withColumn("product_quantity_cleaned", extract_numeric_spark_udf(df["product_quantity"]))

def cost_udf(val):
    if val < 1000:
        return val * random.randint(800, 1000)
    elif val < 10000:
        return val * random.randint(200, 500)
    elif 10000 < val < 100000:
        return val * random.randint(10, 20)
    elif val >= 100000:
        return val * random.randint(1, 5) * 0.01
    else:
        return None

# Register the UDF with Spark
cost_spark_udf = udf(cost_udf, FloatType())

# Apply the UDF to the 'product_quantity_cleaned' column and create a new 'cost_to_recall_in_dollars' column
df = df.withColumn("cost_to_recall_in_dollars", cost_spark_udf(df["product_quantity_cleaned"]))

pd_df_transformed = df.toPandas()

# Show the result
# df.write.mode('overwrite').csv(S3_DATA_OUTPUT_PATH)

# %%
pd_df_transformed
# Out:
#      recall_status                                     recalling_firm  \
# 0       Terminated                             Bio-Logic Systems Corp
# 1       Terminated  Philips Medical Systems North America Co. Phil...
# 2       Terminated                                      Penumbra Inc.
# 3       Terminated                        Baxter Healthcare Corp. Rt.
# 4       Terminated                          Medtronic Navigation, Inc
# ...            ...                                                ...
# 9995    Terminated                            Deerfield Imaging, Inc.
# 9996    Terminated                 Siemens Medical Solutions USA, Inc
# 9997    Terminated            Varian Medical Systems Oncology Systems
# 9998    Terminated                 Siemens Medical Solutions USA Inc.
# 9999    Terminated                Siemens Healthcare Diagnostics, Inc
#
#                       address_1 address_2          city state postal_code  \
# 0             1 Bio Logic Plaza       NaN     Mundelein    IL  60060-3708
# 1     22100 Bothell Everett Hwy       NaN       Bothell    WA  98021-8431
# 2          1351 Harbor Bay Pkwy       NaN       Alameda    CA  94502-6541
# 3               120 & Wilson Rd       NaN    Round Lake    IL       60073
# 4         826 Coal Creek Circle       NaN    Louisville    CO  80027-9710
# ...                         ...       ...           ...   ...         ...
# 9995        5101 Shady Oak Rd S       NaN    Minnetonka    MN  55343-4100
# 9996            4040 Nelson Ave       NaN       Concord    CA  94520-1200
# 9997             911 Hansen Way       NaN     Palo Alto    CA  94304-1028
# 9998          810 Innovation Dr       NaN     Knoxville    TN  37932-2562
# 9999               333 Coney St       NaN  East Walpole    MA  02032-1516
#
#      product_code root_cause_description  \
# 0             GWQ          Device Design
# 1             JAA        Software design
# 2             DQY          Device Design
# 3             FRN          Device Design
# 4             HAW        Labeling design
# ...           ...                    ...
# 9995          HBL          Device Design
# 9996          IYE        Software design
# 9997          IYE        Software design
# 9998          KPS          Device Design
# 9999          JIX          Device Design
#
#                                        product_quantity  device_class  \
# 0                                             311 units             2
# 1                                   19 units in the US.             2
# 2                                            2246 units             2
# 3                                         221,097 pumps             2
# 4                                              6 probes             2
# ...                                                 ...           ...
# 9995                                            3 units             2
# 9996                                           52 units             2
# 9997                                                 18             2
# 9998                                            2 units             2
# 9999  Total = 19,352 (13,881 - 2 pack, 4878 - 6 pack...             2
#
#       product_quantity_cleaned  cost_to_recall_in_dollars
# 0                        311.0               2.780340e+05
# 1                         19.0               1.639700e+04
# 2                       2246.0               1.111770e+06
# 3                     221097.0               2.210970e+03
# 4                          6.0               4.980000e+03
# ...                        ...                        ...
# 9995                       3.0               2.469000e+03
# 9996                      52.0               4.815200e+04
# 9997                      18.0               1.652400e+04
# 9998                       2.0               1.778000e+03
# 9999                   38718.0               7.356420e+05
#
# [10000 rows x 13 columns]

# %%
pd_df_transformed.to_csv('open_fda_transformed.csv')

# %%
s3.Bucket('dsc-bucket-1').upload_file(Filename='open_fda_transformed.csv', Key='open_fda_transformed.csv')
